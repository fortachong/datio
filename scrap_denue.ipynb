# %%
#Importamos las librerías
import requests
import json
import pandas as pd

# %% [markdown]
# Para encontrar el establecimiento ingresamos su razón social y el código postal.
# Para pruebas pueden usar la razón social "GALLAGHER-KAISER DE MEXICO" y el código postal "66269".

# %%
nombre = input('INGRESE EL NOMBRE DE LA PYME: ')
nombre = (nombre.strip()).replace(' ','+')
codigo_postal = input('INGRESE EL CÓDIGO POSTAL DE LA PYME: ')
# Out:
# INGRESE EL NOMBRE DE LA PYME: GALLAGHER-KAISER DE MEXICO
# INGRESE EL CÓDIGO POSTAL DE LA PYME: 66269

# %% [markdown]
# Esto nos dará algunas opciones, elegiremos la correcta con el número entero que le corresponda (en este caso 1 ó 2).

# %%
url_opciones = ('https://www.inegi.org.mx/app/mapa/componente/Espacial.ashx?metodo=ArmabusquedaEstablecimientos&Ac_eco%5B0%5D%5Bsec%5D=&Ac_eco%5B1%5D%5Bsubsec%5D=&Ac_eco%5B2%5D%5Brama%5D=&Ac_eco%5B3%5D%5Bsubra%5D=&Ac_eco%5B4%5D%5Bclase%5D=&Tama%C3%B1o=&Cve_geo%5B0%5D%5Bent%5D=&Cve_geo%5B1%5D%5Bmun%5D=&Cve_geo%5B2%5D%5Bloc%5D=&Txt_gral='+
'&Txt_nom='+nombre+
'&Txt_calle=&Txt_colonia='+
'&Txt_cp='+codigo_postal+
'&Txt_vc=&Txt_prod=&Txt_paisexp=&Txt_paisimp=&Txt_camara=&Txt_mts=&Txt_radio=&Txt_coord=&idee=&Pagini=1&Pagfin=50')

respuesta = requests.post(url_opciones)
opciones = respuesta.json()['obj'][:-1]

print(opciones)

num_opcion = 1
for opcion in opciones:
    nombre_establecimiento = opcion[5]
    print(str(num_opcion)+'. '+nombre_establecimiento)
    num_opcion += 1

establecimiento_correcto = int(input('ELIJA EL ESTABLECIMIENTO CORRECTO: '))
# Out:
# [['8805506', 'NUEVO LEÓN   ', 'San Pedro Garza García', '236211', 'Edificación de naves y plantas industriales, excepto la supervisión', 'FABRICANTES DE TALLERES DE PINTURA GALLAGHER KAISER DE MEXICO', '-100.31879483', '25.64058494'], ['6882371', 'NUEVO LEÓN   ', 'San Pedro Garza García', '236211', 'Edificación de naves y plantas industriales, excepto la supervisión', 'GALLAGHER-KAISER DE MEXICO', '-100.32644501', '25.64940986']]
# 1. FABRICANTES DE TALLERES DE PINTURA GALLAGHER KAISER DE MEXICO
# 2. GALLAGHER-KAISER DE MEXICO
# ELIJA EL ESTABLECIMIENTO CORRECTO: 1

# %% [markdown]
# Ya con esto puedo obtener los datos del establecimiento.

# %%
codigo_1_establecimiento = opciones[establecimiento_correcto - 1][0]
codigo_2_establecimiento = opciones[establecimiento_correcto - 1][3]
url_datos_establecimiento_correcto = ('https://www.inegi.org.mx/app/mapa/componente/APIGeografico/infowindowDenue/'+
                                      codigo_1_establecimiento +'/DENUE/'+codigo_2_establecimiento)
respuesta_final = requests.get(url_datos_establecimiento_correcto)
id_establecimiento = respuesta_final.json()[0]["d1"]
cve_ent = respuesta_final.json()[0]["d2"]
entidad = respuesta_final.json()[0]["d3"]
cve_mun = respuesta_final.json()[0]["d4"]
municipio = respuesta_final.json()[0]["d5"]
cve_loc = respuesta_final.json()[0]["d6"]
localidad = respuesta_final.json()[0]["d7"]
nom_estab = respuesta_final.json()[0]["d8"]
raz_social = respuesta_final.json()[0]["d9"]
codigo_act = respuesta_final.json()[0]["d11"]
nombre_act = respuesta_final.json()[0]["d12"]
per_ocu = respuesta_final.json()[0]["d14"]
tipo_vial = respuesta_final.json()[0]["d15"]
nom_vial = respuesta_final.json()[0]["d16"]
numero_ext = respuesta_final.json()[0]["d17"]
edificio = respuesta_final.json()[0]["d18"]
numero_int = respuesta_final.json()[0]["d19"]
tipo_asent = respuesta_final.json()[0]["d20"]
nomb_asent = respuesta_final.json()[0]["d21"]
nom_CenCom = respuesta_final.json()[0]["d22"]
num_local = respuesta_final.json()[0]["d23"]
cod_postal = respuesta_final.json()[0]["d24"]
ageb = respuesta_final.json()[0]["d25"]
manzana = respuesta_final.json()[0]["d26"]
telefono = respuesta_final.json()[0]["d27"]
correoelec = respuesta_final.json()[0]["d28"]
www = respuesta_final.json()[0]["d30"]
fecha_alta = respuesta_final.json()[0]["d33"]
latitud = respuesta_final.json()[0]["d34"]
longitud = respuesta_final.json()[0]["d35"]
tipo_asent = respuesta_final.json()[0]["d57"]
tipoCenCom = respuesta_final.json()[0]["d58"]
tipo_v_e_1 = respuesta_final.json()[0]["d61"]
nom_v_e_1 = respuesta_final.json()[0]["d62"]
tipo_v_e_2 = respuesta_final.json()[0]["d63"]
nom_v_e_2 = respuesta_final.json()[0]["d64"]
tipo_v_e_3 = respuesta_final.json()[0]["d65"]
nom_v_e_3 = respuesta_final.json()[0]["d66"]
clee = respuesta_final.json()[0]["d68"]

# %% [markdown]
# Entre los datos tenemos (según la documentación técnica de la DENUE).

# %%
df = pd.read_excel('diccionario_variables_DENUE.xlsx')
df['valor_de_ejemplo'] = [id_establecimiento, cve_ent, entidad, cve_mun, municipio, cve_loc, localidad, nom_estab, raz_social,codigo_act,
                          nombre_act, per_ocu, tipo_vial, nom_vial, numero_ext, edificio, numero_int, tipo_asent, nomb_asent,
                          nom_CenCom, num_local, cod_postal, ageb, manzana, telefono, correoelec, www, fecha_alta, latitud,
                          longitud, tipo_asent, tipoCenCom, tipo_v_e_1, nom_v_e_1, tipo_v_e_2, nom_v_e_2, tipo_v_e_3, 
                          nom_v_e_3, clee]
df
# Out:
#    nombre_json nombre_variable  \
# 0           d1              id
# 1           d2         cve_ent
# 2           d3         entidad
# 3           d4         cve_mun
# 4           d5       municipio
# 5           d6         cve_loc
# 6           d7       localidad
# 7           d8       nom_estab
# 8           d9      raz_social
# 9          d11      codigo_act
# 10         d12      nombre_act
# 11         d14         per_ocu
# 12         d15       tipo_vial
# 13         d16        nom_vial
# 14         d17      numero_ext
# 15         d18        edificio
# 16         d19      numero_int
# 17         d20      tipo_asent
# 18         d21      nomb_asent
# 19         d22      nom_CenCom
# 20         d23       num_local
# 21         d24      cod_postal
# 22         d25            ageb
# 23         d26         manzana
# 24         d27        telefono
# 25         d28      correoelec
# 26         d30             www
# 27         d33      fecha_alta
# 28         d34         latitud
# 29         d35        longitud
# 30         d57      tipo_asent
# 31         d58      tipoCenCom
# 32         d61      tipo_v_e_1
# 33         d62       nom_v_e_1
# 34         d63      tipo_v_e_2
# 35         d64       nom_v_e_2
# 36         d65      tipo_v_e_3
# 37         d66       nom_v_e_3
# 38         d68            clee
#
#                                           descripcion  \
# 0   Número  de identificación del DENUE, es una cl...
# 1   Clave que identifica a la entidad federativa e...
# 2   Es el sustantivo propio que identifica a la en...
# 3   Clave que identifica al Municipio estadístico,...
# 4   Es el sustantivo propio que identifica al Muni...
# 5   Clave que identifica a la localidad estadístic...
# 6   Es el sustantivo propio que identifica a la lo...
# 7   Es el nombre comercial o nombre exterior con e...
# 8   Es la forma con que está legalmente constituid...
# 9   La clasificación de las actividades desarrolla...
# 10  Nombre del código de actividad conforme al SCI...
# 11  Comprende al personal contratado directamente ...
# 12  Es la superficie del terreno destinada para el...
# 13  Es el sustantivo propio con el cual se identif...
# 14  Son los valores numéricos que identifican a un...
# 15  Es el sustantivo propio con el que se identifi...
# 16  Son los valores numéricos que identifican el d...
# 17  Es la clasificación que se da al asentamiento ...
# 18  Es el sustantivo propio con el cual se identif...
# 19  Nombre de la plaza, centro comercial, etcétera...
# 20  Dato alfanumérico que corresponde al local en ...
# 21  Clave numérica integrada por cinco dígitos est...
# 22  Es la extensión territorial que corresponde a ...
# 23  Clave geoestadística de la manzana, compuesta ...
# 24  Número telefónico, secuencia de dígitos que pe...
# 25  Correo electrónico, es la serie de caracteres ...
# 26  Son los datos que permiten el acceso a informa...
# 27  Fecha en la que la unidad económica se integró...
# 28  Es la distancia que existe entre la unidad eco...
# 29  Es la distancia que existe entre la unidad eco...
# 30  Es la clasificación que se da al asentamiento ...
# 31  Tipo de plaza, centro comercial, etcétera dond...
# 32  Es la superficie del terreno destinada para el...
# 33  Es el sustantivo propio con el cual se identif...
# 34  Es la superficie del terreno destinada para el...
# 35  Es el sustantivo propio con el cual se identif...
# 36  Es la superficie del terreno destinada para el...
# 37  Es el sustantivo propio con el cual se identif...
# 38  Es la llave única de identificación estadístic...
#
#                                      valor_de_ejemplo
# 0                                             8805506
# 1                                                  19
# 2                                       NUEVO LEÓN
# 3                                                 019
# 4                              San Pedro Garza García
# 5                                                0001
# 6                              San Pedro Garza García
# 7   FABRICANTES DE TALLERES DE PINTURA GALLAGHER K...
# 8             GALLAGHERKAISER DE MEXICO S DE RL DE CV
# 9                                              236211
# 10  Edificación de naves y plantas industriales, e...
# 11                                     0 a 5 personas
# 12                                              CALLE
# 13                              PEDRO RAMIREZ VAZQUEZ
# 14                                                200
# 15
# 16
# 17                                        RESIDENCIAL
# 18                                      VALLE ORIENTE
# 19
# 20
# 21                                              66269
# 22                                               044A
# 23                                                045
# 24                                         8123514221
# 25                    MARTHA.MENDEZ@GKDEMEXICO.CPM.MX
# 26                                     WWW.GKCORP.CPM
# 27                                            2019-11
# 28                                        25.64058494
# 29                                      -100.31879483
# 30                                        RESIDENCIAL
# 31
# 32                                            AVENIDA
# 33                                    LAZARO CARDENAS
# 34                                            AVENIDA
# 35                             EUGENIO GARZA LA GÜERA
# 36                                              CALLE
# 37                             DAVID ALFARO SIQUEIROS
# 38                       19019236211000191000040374S5
